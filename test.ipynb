# %%
# !pip install mediapipe
# Out:
# Collecting mediapipe
#   Downloading mediapipe-0.10.13-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.7 kB)
# Collecting absl-py (from mediapipe)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: attrs>=19.1.0 in /home/deadbytes/Documents/ML/lib/python3.12/site-packages (from mediapipe) (23.2.0)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting jax (from mediapipe)
#   Downloading jax-0.4.27-py3-none-any.whl.metadata (23 kB)
# Collecting jaxlib (from mediapipe)
#   Downloading jaxlib-0.4.27-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting matplotlib (from mediapipe)
#   Downloading matplotlib-3.8.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy in /home/deadbytes/Documents/ML/lib/python3.12/site-packages (from mediapipe) (1.26.4)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting protobuf<5,>=4.25.3 (from mediapipe)
#   Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-any.whl.metadata (1.4 kB)
# Collecting CFFI>=1.0 (from sounddevice>=0.4.4->mediapipe)
#   Downloading cffi-1.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting ml-dtypes>=0.2.0 (from jax->mediapipe)
#   Downloading ml_dtypes-0.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting opt-einsum (from jax->mediapipe)
#   Downloading opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting scipy>=1.9 (from jax->mediapipe)
#   Downloading scipy-1.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting contourpy>=1.0.1 (from matplotlib->mediapipe)
#   Downloading contourpy-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->mediapipe)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->mediapipe)
#   Downloading fonttools-4.51.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.5/159.5 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib->mediapipe)
#   Downloading kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /home/deadbytes/Documents/ML/lib/python3.12/site-packages (from matplotlib->mediapipe) (24.0)
# Requirement already satisfied: pillow>=8 in /home/deadbytes/Documents/ML/lib/python3.12/site-packages (from matplotlib->mediapipe) (10.3.0)
# Collecting pyparsing>=2.3.1 (from matplotlib->mediapipe)
#   Downloading pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/deadbytes/Documents/ML/lib/python3.12/site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Collecting pycparser (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe)
#   Downloading pycparser-2.22-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: six>=1.5 in /home/deadbytes/Documents/ML/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.13-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 7.6 MB/s eta 0:00:0000:0100:01
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 9.8 MB/s eta 0:00:00
# Downloading sounddevice-0.4.6-py3-none-any.whl (31 kB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 15.6 MB/s eta 0:00:00
# Downloading jax-0.4.27-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.7 MB/s eta 0:00:0000:0100:01m
# Downloading jaxlib-0.4.27-cp312-cp312-manylinux2014_x86_64.whl (77.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 MB 1.7 MB/s eta 0:00:0000:0100:02
# Downloading matplotlib-3.8.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 3.0 MB/s eta 0:00:0000:0100:01
# Downloading opencv_contrib_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (68.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.3/68.3 MB 13.0 MB/s eta 0:00:0000:0100:01
# Downloading cffi-1.16.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (477 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 477.6/477.6 kB 11.5 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.2.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.2/309.2 kB 6.2 MB/s eta 0:00:00a 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.51.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 3.3 MB/s eta 0:00:0000:0100:01
# Downloading kiwisolver-1.4.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading ml_dtypes-0.4.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.8 MB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 3.3 MB/s eta 0:00:00
# Downloading scipy-1.13.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 4.4 MB/s eta 0:00:0000:0100:01
# Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.3 MB/s eta 0:00:00
# Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.6/117.6 kB 3.8 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, scipy, pyparsing, pycparser, protobuf, opt-einsum, opencv-contrib-python, ml-dtypes, kiwisolver, fonttools, cycler, contourpy, absl-py, matplotlib, jaxlib, jax, CFFI, sounddevice, mediapipe
# Successfully installed CFFI-1.16.0 absl-py-2.1.0 contourpy-1.2.1 cycler-0.12.1 flatbuffers-24.3.25 fonttools-4.51.0 jax-0.4.27 jaxlib-0.4.27 kiwisolver-1.4.5 matplotlib-3.8.4 mediapipe-0.10.13 ml-dtypes-0.4.0 opencv-contrib-python-4.9.0.80 opt-einsum-3.3.0 protobuf-4.25.3 pycparser-2.22 pyparsing-3.1.2 scipy-1.13.0 sounddevice-0.4.6

# %%
# !pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /home/deadbytes/Documents/ML/lib/python3.12/site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 3.9 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80

# %%
import cv2
import mediapipe as mp

def main():
    # Initialize MediaPipe Hand model
    mp_hands = mp.solutions.hands
    hands = mp_hands.Hands(static_image_mode=False, max_num_hands=1, min_detection_confidence=0.5, min_tracking_confidence=0.5)
    
    # Initialize OpenCV VideoCapture
    
    cap = cv2.VideoCapture(0)
    
    while cap.isOpened():
        # Read frame from camera
        ret, frame = cap.read()
        if not ret:
            break
        
        # Convert the BGR image to RGB
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Process the frame
        results = hands.process(rgb_frame)
        
        if results.multi_hand_landmarks:
            for hand_landmarks in results.multi_hand_landmarks:
                for idx, landmark in enumerate(hand_landmarks.landmark):
                    # Get the coordinates of each finger's joints
                    finger_coordinates = {
                        "thumb": [
                            hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC],
                            hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP]
                        ],
                        "index": [
                            hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP]
                        ],
                        "middle": [
                            hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP]
                        ],
                        "ring": [
                            hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP]
                        ],
                        "pinky": [
                            hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP],
                            hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP]
                        ]
                    }
                    
                    # Convert normalized coordinates to pixel coordinates
                    height, width, _ = frame.shape
                    for finger, joints in finger_coordinates.items():
                        for joint in joints:
                            cx, cy = int(joint.x * width), int(joint.y * height)
                            joint.x = cx
                            joint.y = cy
                    
                    # Draw circles at the coordinates
                    for finger, joints in finger_coordinates.items():
                        for joint in joints:
                            cv2.circle(frame, (int(joint.x), int(joint.y)), 5, (0, 255, 0), cv2.FILLED)
        
        # Display the frame
        cv2.imshow('Hand Tracking', frame)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1715148009.923487    6849 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1715148009.926217    6918 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 Mesa 24.0.5-1ubuntu1), renderer: AMD Radeon Graphics (radeonsi, renoir, LLVM 17.0.6, DRM 3.57, 6.8.0-31-generic)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# /home/deadbytes/Documents/ML/lib/python3.12/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 85
#      82     cv2.destroyAllWindows()
#      84 if __name__ == "__main__":
# ---> 85     main()
#
# Cell In[1], line 73, in main()
#      71             for finger, joints in finger_coordinates.items():
#      72                 for joint in joints:
# ---> 73                     cv2.circle(frame, (int(joint.x), int(joint.y)), 5, (0, 255, 0), cv2.FILLED)
#      75 # Display the frame
#      76 cv2.imshow('Hand Tracking', frame)
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'circle'
# > Overload resolution failed:
# >  - Can't parse 'center'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'center'. Sequence item with index 0 has a wrong type
